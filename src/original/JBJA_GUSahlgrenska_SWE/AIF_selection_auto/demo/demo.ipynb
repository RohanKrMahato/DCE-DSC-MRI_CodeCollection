# %%
import sys
sys.path.append('..')
from AIF_selection_automatic import AutoAifSel
from os import getcwd
from os.path import join
from IPython.display import Image

base = join(getcwd(),'data')
brain_mask_fn =  join(base, 'brain_mask_3d_anon.nii.gz') #MANDATORY filepath to brain_mask file
conc_fn = join(base, '4d_concentration_masked_anon.nii.gz') # MANDATORY filepath to conc file 
ROI_fn = join(base, 'MCAsin_anon.nii') # MANDATORY for non-Mouridsen AIF-selection

# %% [markdown]
# ## Whole brain automatic AIF selection as originally published by Mouridsen et al. 2006

# %%
plot_config = 5
do_Mouridsen2006 = True
plot_suffix = ''

AIF_vec, AIF_ROI  = AutoAifSel(conc_fn, brain_mask_fn, getcwd(), plot_config, plot_suffix, do_Mouridsen2006).return_vals()

Image(filename='auto_AIF_result_fig_Mouridsen' + plot_suffix + '.jpeg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:971: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:971: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:380: MatplotlibDeprecationWarning:
# cycling among columns of inputs with non-matching shapes is deprecated.
#   cbook.warn_deprecated("2.2", "cycling among columns of inputs "

# %% [markdown]
# ## Semi-automatic, ROI-defined AIF selection

# %%
plot_config = 5
do_Mouridsen2006 = False
plot_suffix = ''

AIF_vec, AIF_ROI  = AutoAifSel(conc_fn, brain_mask_fn, getcwd(), plot_config, plot_suffix, do_Mouridsen2006, ROI_fn).return_vals()

Image(filename='auto_AIF_result_fig' + plot_suffix + '.jpeg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:971: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:380: MatplotlibDeprecationWarning:
# cycling among columns of inputs with non-matching shapes is deprecated.
#   cbook.warn_deprecated("2.2", "cycling among columns of inputs "
